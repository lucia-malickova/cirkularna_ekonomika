# %% [markdown]
# # AI Circular Economy Advisor
#
# Ask this assistant for sustainable practices in the hospitality sector, such as reducing waste, improving recycling, or implementing energy-saving solutions.

# %%
import openai

openai.api_key = "your_api_key_here"  # Replace with your OpenAI API key

def ask_advisor(question):
    response = openai.ChatCompletion.create(
        model="gpt-4",
        messages=[
            {"role": "system", "content": "You are a circular economy advisor for small businesses in tourism and hospitality."},
            {"role": "user", "content": question}
        ]
    )
    return response['choices'][0]['message']['content']

# Example usage
ask_advisor("How can a small guesthouse reduce single-use plastics?")
